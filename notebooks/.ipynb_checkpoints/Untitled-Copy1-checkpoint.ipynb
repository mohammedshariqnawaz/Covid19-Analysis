# %%
import subprocess
import os
import requests
from bs4 import BeautifulSoup
import json
import matplotlib as mlp
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.max_rows',500)

# %%
df_plot=pd.read_csv('..\data\processed\COVID_small_flat_table.csv')
df_plot.head()
# Out:
#          date  Canada  France  China  Australia  Denmark  United Kingdom
# 0  2020-01-22       0       0    548          0        0               0
# 1  2020-01-23       0       0    643          0        0               0
# 2  2020-01-24       0       2    920          0        0               0
# 3  2020-01-25       0       3   1406          0        0               0
# 4  2020-01-26       1       3   2075          4        0               0

# %%
mlp.rcParams['figure.figsize']=(16,10)

# %%
df_plot.set_index('date').plot()

# %%
plt.figure();
ax=df_plot.set_index('date').plot()
plt.ylim(10,30000)
ax.set_yscale('log')

# %%
import plotly.graph_objects as go
import plotly
plotly.__version__
# Out:
# '4.8.1'

# %%
import webbrowser as wb
urL='https://www.google.com'
chrome_path="C:\\Program Files (x86)\\Google\\Chrome\\Application\\chrome.exe"
wb.register('chrome', None,wb.BackgroundBrowser(chrome_path))
wb.get('chrome').open_new_tab(urL)
# Out:
# True

# %%
fig=go.Figure()
country_list= ['Canada','France', 'China', 'Australia', 'Denmark', 'United Kingdom']
for each in country_list:
    fig.add_trace(go.Scatter(
    x=df_plot.date,y=df_plot[each],mode="markers+lines"))

fig.update_layout(
    xaxis_title="Time",
    yaxis_title="Confirmed people,log-scale",)
fig.update_yaxes(type='log',range=[1.1,5.5])

wb.open_new_tab('http://www.google.com')
fig.update_layout(xaxis_rangeslider_visible=True)
fig.show(renderer='chrome')

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
app=dash.Dash()
app.layout=html.Div([dcc.Graph(figure=fig)])

# %%
app.layout=html.Div([html.Label('Multi-Select Country'),
                    dcc.Dropdown(id='country_drop_down',options=[
                        {'label':'Denmark','value':'Denmark'},
                        {'label':'Australia','value':'Australia'},
                        {'label':'Canada','value':'Canada'},
                        {'label':'France','value':'France'},
                    ],
                                value=['Denmark','France'],multi=True),dcc.Graph(figure=fig, id='main_window_slope')])

# %%
from dash.dependencies import Input, Output

@app.callback(
    Output('main_window_slope', 'figure'),
    [Input('country_drop_down', 'value')])
def update_figure(country_list):
    
    traces = [] 
    for each in country_list:
        traces.append(dict(x=df_plot.date,
                                y=df_plot[each],
                                mode='markers+lines',
                                opacity=0.9,
                                line_width=2,
                                marker_size=4, 
                                name=each
                        )
                )
        
    return {
            'data': traces,
            'layout': dict (
                width=1280,
                height=720,
                xaxis_title="Time",
                yaxis_title="Confirmed infected people (source johns hopkins csse, log-scale)",
                xaxis={'tickangle':-45,
                        'nticks':20,
                        'tickfont':dict(size=14,color="#7f7f7f"),
                        
                      },
                yaxis={'type':"log",
                       'range':'[1.1,5.5]'
                      }
        )
    }

# %%
app.run_server(debug=True, use_reloader=False)
# Out:
# Running on http://127.0.0.1:8050/
# Debugger PIN: 226-398-930
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
